# %% [markdown]
# <a href="https://colab.research.google.com/github/duckduck123go/Momentum-Trading-Strategy/blob/main/Quant_PS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')
import yfinance as yf
import warnings
warnings.filterwarnings("ignore")

# %%
# Download the historical price data for NIFTY 50 stocks
nifty_50_tickers = [
    "RELIANCE.NS", "HDFCBANK.NS", "ICICIBANK.NS", "INFY.NS", "TCS.NS",
    "KOTAKBANK.NS", "ITC.NS", "LT.NS", "HINDUNILVR.NS", "SBIN.NS",
    "BHARTIARTL.NS", "BAJFINANCE.NS", "ASIANPAINT.NS", "DMART.NS",
    "MARUTI.NS", "AXISBANK.NS", "HCLTECH.NS", "M&M.NS", "ULTRACEMCO.NS",
    "TITAN.NS", "SUNPHARMA.NS", "ONGC.NS", "WIPRO.NS", "ADANIENT.NS",
    "NTPC.NS", "POWERGRID.NS", "INDUSINDBK.NS", "TATASTEEL.NS", "BAJAJFINSV.NS",
    "DIVISLAB.NS", "JSWSTEEL.NS", "TECHM.NS", "HDFCLIFE.NS", "CIPLA.NS",
    "BPCL.NS", "APOLLOHOSP.NS", "BRITANNIA.NS", "COALINDIA.NS", "HEROMOTOCO.NS",
    "DRREDDY.NS", "TATAMOTORS.NS", "GRASIM.NS", "SBILIFE.NS", "EICHERMOT.NS",
    "UPL.NS", "NESTLEIND.NS", "SHREECEM.NS", "ADANIPORTS.NS", "BPCL.NS"
]

# Download historical data from Yahoo Finance
start_date = "2019-01-01"
end_date = "2023-12-01"
data = yf.download(nifty_50_tickers, start=start_date, end=end_date)

# Install pandas_ta if not already installed
# !pip install pandas_ta
import pandas_ta as ta

# Momentum score calculation function
def calculate_momentum_score(data):
    momentum_scores = pd.DataFrame()

    # Loop through each stock's data
    for ticker in data['Adj Close'].columns:
        if ticker not in nifty_50_tickers:
            continue
        try:
          stock_close = data['Adj Close'][ticker]
          stock_high = data['High'][ticker]
          stock_low = data['Low'][ticker]
          stock_volume = data['Volume'][ticker]
        except KeyError:
          continue

        # Ensure at least 21 data points are available
        if len(stock_close) < 21:
            continue

        # Calculate technical indicators
        rsi = ta.rsi(stock_close, length=14)
        roc = ta.roc(stock_close, length=12)
        volatility = stock_close.pct_change().rolling(window=21).std() * np.sqrt(252)  # Annualized volatility

        # VWAP calculation with high, low, close, and volume
        vwap = ta.vwap(stock_high, stock_low, stock_close, stock_volume, length=20)

        # Normalization of technical indicators
        normalized_rsi = rsi / 100
        normalized_roc = roc / 100
        normalized_vwap = np.log(vwap + 1)

        # Volatility dampening
        volatility_dampening = 1 / (1 + np.exp(volatility))

        # Calculate momentum score based on ROC value
        if roc.iloc[-1] > 0:  # Latest value of ROC > 0
            momentum_scores[ticker] = normalized_rsi * normalized_roc * volatility_dampening * normalized_vwap
        else:
            momentum_scores[ticker] = (1 - normalized_rsi) * normalized_roc * volatility_dampening * normalized_vwap

    momentum_scores = momentum_scores.iloc[21:]


    return momentum_scores

# Run the momentum score calculation
momentum_scores = calculate_momentum_score(data)
momentum_scores.head()
# Out:
# [*********************100%***********************]  48 of 48 completed
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218909 sha256=184900c8637beedd4bbdc32043cb4322f9aa48f3cf153e3677f011e7ad855124
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0
#                            ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  \
# Date
# 2019-01-30 00:00:00+00:00    -0.036671      -0.065293      -0.003909
# 2019-01-31 00:00:00+00:00    -0.043274      -0.082070      -0.004649
# 2019-02-01 00:00:00+00:00    -0.033148      -0.088728      -0.008785
# 2019-02-04 00:00:00+00:00    -0.071839      -0.098209      -0.062432
# 2019-02-05 00:00:00+00:00    -0.068337      -0.107974      -0.080863
#
#                            ASIANPAINT.NS  AXISBANK.NS  BAJAJFINSV.NS  \
# Date
# 2019-01-30 00:00:00+00:00       0.002188     0.094199      -0.022867
# 2019-01-31 00:00:00+00:00       0.009256     0.202025      -0.065262
# 2019-02-01 00:00:00+00:00       0.111055     0.165783      -0.058373
# 2019-02-04 00:00:00+00:00       0.087302     0.135535      -0.051325
# 2019-02-05 00:00:00+00:00       0.077300     0.211194      -0.035302
#
#                            BAJFINANCE.NS  BHARTIARTL.NS   BPCL.NS  \
# Date
# 2019-01-30 00:00:00+00:00       0.032641      -0.072032  0.019623
# 2019-01-31 00:00:00+00:00      -0.019390      -0.087866  0.010241
# 2019-02-01 00:00:00+00:00       0.034667      -0.073118 -0.015265
# 2019-02-04 00:00:00+00:00       0.038076      -0.076388 -0.037891
# 2019-02-05 00:00:00+00:00       0.038621      -0.009868 -0.036618
#
#                            BRITANNIA.NS  ...  SHREECEM.NS  SUNPHARMA.NS  \
# Date                                     ...
# 2019-01-30 00:00:00+00:00      0.070617  ...    -0.002071     -0.075110
# 2019-01-31 00:00:00+00:00      0.009538  ...     0.014000     -0.070431
# 2019-02-01 00:00:00+00:00      0.059108  ...    -0.001715     -0.073853
# 2019-02-04 00:00:00+00:00      0.047138  ...     0.002287     -0.027443
# 2019-02-05 00:00:00+00:00     -0.002432  ...     0.012768      0.046209
#
#                            TATAMOTORS.NS  TATASTEEL.NS    TCS.NS  TECHM.NS  \
# Date
# 2019-01-30 00:00:00+00:00      -0.042126     -0.004834  0.220402  0.074143
# 2019-01-31 00:00:00+00:00      -0.028568      0.002705  0.198902  0.061933
# 2019-02-01 00:00:00+00:00      -0.026650      0.000242  0.222914  0.126527
# 2019-02-04 00:00:00+00:00      -0.031129      0.004767  0.216240  0.119560
# 2019-02-05 00:00:00+00:00      -0.042606     -0.008424  0.193868  0.115484
#
#                            TITAN.NS  ULTRACEMCO.NS    UPL.NS  WIPRO.NS
# Date
# 2019-01-30 00:00:00+00:00  0.021729      -0.068929 -0.006131  0.288584
# 2019-01-31 00:00:00+00:00  0.060203      -0.085802  0.024722  0.222164
# 2019-02-01 00:00:00+00:00  0.064350      -0.105156  0.030234  0.196771
# 2019-02-04 00:00:00+00:00  0.152710      -0.099310  0.003638  0.201212
# 2019-02-05 00:00:00+00:00  0.269892      -0.094920  0.069936  0.116092
#
# [5 rows x 48 columns]

# %%
data.head()
# Out:
# Price                       Adj Close                              \
# Ticker                    ADANIENT.NS ADANIPORTS.NS APOLLOHOSP.NS
# Date
# 2019-01-01 00:00:00+00:00  155.247131    375.101196   1243.499390
# 2019-01-02 00:00:00+00:00  152.877701    367.676270   1235.987793
# 2019-01-03 00:00:00+00:00  150.557632    364.590668   1243.744873
# 2019-01-04 00:00:00+00:00  150.607010    368.495941   1269.618286
# 2019-01-07 00:00:00+00:00  149.323547    368.013763   1258.915527
#
# Price                                                              \
# Ticker                    ASIANPAINT.NS AXISBANK.NS BAJAJFINSV.NS
# Date
# 2019-01-01 00:00:00+00:00   1311.242554  623.803833    650.470459
# 2019-01-02 00:00:00+00:00   1322.475708  616.594299    636.711914
# 2019-01-03 00:00:00+00:00   1327.255981  604.561829    636.642212
# 2019-01-04 00:00:00+00:00   1324.913696  616.146790    639.349976
# 2019-01-07 00:00:00+00:00   1334.617310  633.897461    639.020874
#
# Price                                                              \
# Ticker                    BAJFINANCE.NS BHARTIARTL.NS     BPCL.NS
# Date
# 2019-01-01 00:00:00+00:00   2608.035645    282.769745  121.127693
# 2019-01-02 00:00:00+00:00   2566.021973    276.707245  118.076408
# 2019-01-03 00:00:00+00:00   2538.683350    277.459534  116.278595
# 2019-01-04 00:00:00+00:00   2528.720215    285.380646  118.571198
# 2019-01-07 00:00:00+00:00   2506.682373    287.593231  117.284691
#
# Price                                   ...      Volume               \
# Ticker                    BRITANNIA.NS  ... SHREECEM.NS SUNPHARMA.NS
# Date                                    ...
# 2019-01-01 00:00:00+00:00  2792.422119  ...       12171      8487116
# 2019-01-02 00:00:00+00:00  2804.841064  ...       13931      9656878
# 2019-01-03 00:00:00+00:00  2821.983398  ...       24843      9479511
# 2019-01-04 00:00:00+00:00  2810.104980  ...       30506      6228693
# 2019-01-07 00:00:00+00:00  2829.093018  ...       11758      4118235
#
# Price                                                                   \
# Ticker                    TATAMOTORS.NS TATASTEEL.NS   TCS.NS TECHM.NS
# Date
# 2019-01-01 00:00:00+00:00       6715543     41281730  1094883   815535
# 2019-01-02 00:00:00+00:00      13410104    117473500  2100463  2576769
# 2019-01-03 00:00:00+00:00       9321842    135329440  2611668  3558015
# 2019-01-04 00:00:00+00:00      17650435    104800720  4280862  3926171
# 2019-01-07 00:00:00+00:00      21438351     84067870  1856423  1885000
#
# Price
# Ticker                    TITAN.NS ULTRACEMCO.NS   UPL.NS WIPRO.NS
# Date
# 2019-01-01 00:00:00+00:00  2064502         92921  2415372  2018271
# 2019-01-02 00:00:00+00:00  2672587        143828  1962064  4411069
# 2019-01-03 00:00:00+00:00  3292918        223538  1579716  4723040
# 2019-01-04 00:00:00+00:00  2340304        220079  1590477  3207036
# 2019-01-07 00:00:00+00:00  5337211        220371  2384899  2538138
#
# [5 rows x 288 columns]

# %%
data_2= yf.download(nifty_50_tickers, start=start_date, end=end_date)['Adj Close']
data_2.head()
# Out:
# [*********************100%***********************]  48 of 48 completed
# Ticker                     ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  \
# Date
# 2019-01-01 00:00:00+00:00   155.247131     375.101196    1243.499390
# 2019-01-02 00:00:00+00:00   152.877716     367.676300    1235.987793
# 2019-01-03 00:00:00+00:00   150.557648     364.590668    1243.744751
# 2019-01-04 00:00:00+00:00   150.606995     368.495941    1269.618286
# 2019-01-07 00:00:00+00:00   149.323532     368.013763    1258.915649
#
# Ticker                     ASIANPAINT.NS  AXISBANK.NS  BAJAJFINSV.NS  \
# Date
# 2019-01-01 00:00:00+00:00    1311.242432   623.803955     650.470581
# 2019-01-02 00:00:00+00:00    1322.475830   616.594360     636.711914
# 2019-01-03 00:00:00+00:00    1327.255737   604.561768     636.642151
# 2019-01-04 00:00:00+00:00    1324.913696   616.146790     639.349915
# 2019-01-07 00:00:00+00:00    1334.617676   633.897400     639.020813
#
# Ticker                     BAJFINANCE.NS  BHARTIARTL.NS     BPCL.NS  \
# Date
# 2019-01-01 00:00:00+00:00    2608.035645     282.769745  121.127678
# 2019-01-02 00:00:00+00:00    2566.022217     276.707245  118.076408
# 2019-01-03 00:00:00+00:00    2538.683838     277.459564  116.278603
# 2019-01-04 00:00:00+00:00    2528.720215     285.380615  118.571182
# 2019-01-07 00:00:00+00:00    2506.682617     287.593231  117.284691
#
# Ticker                     BRITANNIA.NS  ...   SHREECEM.NS  SUNPHARMA.NS  \
# Date                                     ...
# 2019-01-01 00:00:00+00:00   2792.422119  ...  16607.578125    409.157593
# 2019-01-02 00:00:00+00:00   2804.841064  ...  16574.996094    415.291962
# 2019-01-03 00:00:00+00:00   2821.983643  ...  16583.261719    411.564178
# 2019-01-04 00:00:00+00:00   2810.105225  ...  16376.514648    409.393585
# 2019-01-07 00:00:00+00:00   2829.092773  ...  16557.138672    406.562347
#
# Ticker                     TATAMOTORS.NS  TATASTEEL.NS       TCS.NS  \
# Date
# 2019-01-01 00:00:00+00:00     172.379135     20.220043  1743.075684
# 2019-01-02 00:00:00+00:00     167.509384     19.353607  1761.854858
# 2019-01-03 00:00:00+00:00     165.024826     18.867464  1740.464844
# 2019-01-04 00:00:00+00:00     169.894577     19.118378  1719.303589
# 2019-01-07 00:00:00+00:00     174.267410     19.034084  1738.586426
#
# Ticker                       TECHM.NS    TITAN.NS  ULTRACEMCO.NS      UPL.NS  \
# Date
# 2019-01-01 00:00:00+00:00  605.718384  898.259277    3903.288574  471.213684
# 2019-01-02 00:00:00+00:00  599.779968  902.276245    3900.270752  473.089783
# 2019-01-03 00:00:00+00:00  582.259521  901.356812    3797.022217  466.929901
# 2019-01-04 00:00:00+00:00  573.709900  898.694946    3811.139160  473.027222
# 2019-01-07 00:00:00+00:00  579.100830  913.794922    3823.016846  477.623688
#
# Ticker                       WIPRO.NS
# Date
# 2019-01-01 00:00:00+00:00  239.273010
# 2019-01-02 00:00:00+00:00  238.467270
# 2019-01-03 00:00:00+00:00  238.430649
# 2019-01-04 00:00:00+00:00  237.661499
# 2019-01-07 00:00:00+00:00  237.515015
#
# [5 rows x 48 columns]

# %%
long_stock = None
short_stock = None
capital = 1000000
portfolio_value = capital
trading_days = pd.date_range(start="2021-01-01", end="2021-12-31", freq='B')

long_position_size  = capital*0.5
short_position_size = capital*0.5

long_entry_price = None
short_entry_price = None

for date in trading_days:
  data.index = data.index.tz_localize(None)
  data_2.index = data_2.index.tz_localize(None)
  if date not in data.index:
    continue

  momentum_scores = calculate_momentum_score(data.loc[:date])

  if momentum_scores.empty:
    continue

  final_momentum_scores = momentum_scores.iloc[-1].sort_values(ascending=False)

  if long_stock is None and short_stock is None:
    long_stock = final_momentum_scores.index[0] #stock with highest momentum
    short_stock = final_momentum_scores.index[-1] #stock with lowest momentu

    long_entry_price = data_2[long_stock].loc[date]
    short_entry_price = data_2[short_stock].loc[date]

    print(f"Initial Long Position: {long_stock} at {long_entry_price}, Initial Short Position: {short_stock} at {short_entry_price}")

  if long_stock is not None and short_stock is not None:
    new_long_stock_rank = final_momentum_scores.index.get_loc(long_stock)+ 1
    new_short_stock_rank = final_momentum_scores.index.get_loc(short_stock) +1

    if new_long_stock_rank>5:
      print(f"Exit long position on {long_stock} at {data_2[long_stock].loc[date]}")
      long_exit_value = long_position_size * (data_2[long_stock].loc[date] / long_entry_price)  # Value at exit
      portfolio_value += (long_exit_value - long_position_size)  # Update portfolio value
      long_stock = final_momentum_scores.index[0]  # New long stock
      long_entry_price = data_2[long_stock].loc[date]  # Capture new entry price
      long_position_size = portfolio_value * 0.5  # Reallocate half of portfolio to long
      print(f"Enter new long position on {long_stock} at {long_entry_price}")

    if new_short_stock_rank < (len(final_momentum_scores) - 4):
      print(f"Exit short position on {short_stock} at {data_2[short_stock].loc[date]}")
      short_exit_value = short_position_size * (short_entry_price / data_2[short_stock].loc[date])  # Value at exit
      portfolio_value += (short_exit_value - short_position_size)  # Update portfolio value
      short_stock = final_momentum_scores.index[-1]  # New short stock
      short_entry_price = data_2[short_stock].loc[date]  # Capture new entry price
      short_position_size = portfolio_value * 0.5  # Reallocate half of portfolio to short
      print(f"Enter new short position on {short_stock} at {short_entry_price}")

print(f"Final Portfolio Value: ₹{portfolio_value:.2f}")
print(f"Final Long Position: {long_stock} at {long_entry_price}, Final Short Position: {short_stock} at {short_entry_price}")
# Out:
# Initial Long Position: ASIANPAINT.NS at 2689.97509765625, Initial Short Position: BRITANNIA.NS at 3336.078125
# Exit long position on ASIANPAINT.NS at 2668.798583984375
# Enter new long position on DMART.NS at 2898.449951171875
# Exit long position on DMART.NS at 2921.449951171875
# Enter new long position on ADANIENT.NS at 516.8106689453125
# Exit long position on ADANIENT.NS at 516.7109985351562
# Enter new long position on WIPRO.NS at 423.0527038574219
# Exit short position on BRITANNIA.NS at 3395.781005859375
# Enter new short position on NESTLEIND.NS at 1729.120849609375
# Exit short position on NESTLEIND.NS at 1741.9456787109375
# Enter new short position on BAJFINANCE.NS at 4807.15380859375
# Exit long position on WIPRO.NS at 431.2640075683594
# Enter new long position on TATAMOTORS.NS at 258.69293212890625
# Exit short position on BAJFINANCE.NS at 5044.6357421875
# Enter new short position on DMART.NS at 2719.14990234375
# Exit short position on DMART.NS at 2862.75
# Enter new short position on DIVISLAB.NS at 3426.42333984375
# Exit short position on DIVISLAB.NS at 3348.029541015625
# Enter new short position on DRREDDY.NS at 4318.345703125
# Exit long position on TATAMOTORS.NS at 333.8758850097656
# Enter new long position on SBIN.NS at 373.7210693359375
# Exit short position on DRREDDY.NS at 4723.9814453125
# Enter new short position on HINDUNILVR.NS at 2099.849853515625
# Exit short position on HINDUNILVR.NS at 2066.546142578125
# Enter new short position on EICHERMOT.NS at 2496.16064453125
# Exit long position on SBIN.NS at 372.3562927246094
# Enter new long position on ADANIENT.NS at 797.6600952148438
# Exit short position on EICHERMOT.NS at 2499.154541015625
# Enter new short position on BHARTIARTL.NS at 515.4136962890625
# Exit long position on ADANIENT.NS at 871.7252807617188
# Enter new long position on GRASIM.NS at 1340.398681640625
# Exit short position on BHARTIARTL.NS at 509.99652099609375
# Enter new short position on HEROMOTOCO.NS at 2815.90185546875
# Exit long position on GRASIM.NS at 1378.146728515625
# Enter new long position on JSWSTEEL.NS at 422.57037353515625
# Exit short position on HEROMOTOCO.NS at 2623.458984375
# Enter new short position on BAJFINANCE.NS at 4550.15673828125
# Exit short position on BAJFINANCE.NS at 4600.6201171875
# Enter new short position on ULTRACEMCO.NS at 5941.41796875
# Exit short position on ULTRACEMCO.NS at 6145.08154296875
# Enter new short position on HCLTECH.NS at 807.8960571289062
# Exit short position on HCLTECH.NS at 802.3213500976562
# Enter new short position on BRITANNIA.NS at 3290.006591796875
# Exit long position on JSWSTEEL.NS at 671.9172973632812
# Enter new long position on TATASTEEL.NS at 48.666770935058594
# Exit short position on BRITANNIA.NS at 3328.2177734375
# Enter new short position on SHREECEM.NS at 26344.494140625
# Exit long position on TATASTEEL.NS at 45.60845184326172
# Enter new long position on UPL.NS at 734.4301147460938
# Exit short position on SHREECEM.NS at 27240.984375
# Enter new short position on BHARTIARTL.NS at 513.6240844726562
# Exit long position on UPL.NS at 780.64892578125
# Enter new long position on SBIN.NS at 407.13525390625
# Exit short position on BHARTIARTL.NS at 515.3170166015625
# Enter new short position on SUNPHARMA.NS at 651.6619873046875
# Exit long position on SBIN.NS at 405.8119812011719
# Enter new long position on ADANIENT.NS at 1632.3775634765625
# Exit long position on ADANIENT.NS at 1497.713623046875
# Enter new long position on RELIANCE.NS at 2051.072021484375
# Exit short position on SUNPHARMA.NS at 650.936767578125
# Enter new short position on M&M.NS at 769.55517578125
# Exit long position on RELIANCE.NS at 2020.6473388671875
# Enter new long position on DMART.NS at 3310.39990234375
# Exit short position on M&M.NS at 767.223388671875
# Enter new short position on ADANIPORTS.NS at 689.3435668945312
# Exit long position on DMART.NS at 3311.0
# Enter new long position on INFY.NS at 1398.1021728515625
# Exit short position on ADANIPORTS.NS at 697.807373046875
# Enter new short position on SHREECEM.NS at 26641.62890625
# Exit long position on INFY.NS at 1455.78564453125
# Enter new long position on APOLLOHOSP.NS at 3666.46044921875
# Exit short position on SHREECEM.NS at 27385.40625
# Enter new short position on TATAMOTORS.NS at 314.9434814453125
# Exit long position on APOLLOHOSP.NS at 3721.958251953125
# Enter new long position on LT.NS at 1541.53173828125
# Exit long position on LT.NS at 1543.8306884765625
# Enter new long position on ULTRACEMCO.NS at 7334.16796875
# Exit short position on TATAMOTORS.NS at 289.6009216308594
# Enter new short position on DRREDDY.NS at 4744.94921875
# Exit long position on ULTRACEMCO.NS at 7625.4853515625
# Enter new long position on SUNPHARMA.NS at 759.7646484375
# Exit short position on DRREDDY.NS at 4566.45068359375
# Enter new short position on SHREECEM.NS at 25674.453125
# Exit long position on SUNPHARMA.NS at 758.2176513671875
# Enter new long position on APOLLOHOSP.NS at 4867.67431640625
# Exit short position on SHREECEM.NS at 26245.1953125
# Enter new short position on MARUTI.NS at 6443.3076171875
# Exit short position on MARUTI.NS at 6674.86669921875
# Enter new short position on JSWSTEEL.NS at 659.0302734375
# Exit long position on APOLLOHOSP.NS at 4963.74072265625
# Enter new long position on BAJFINANCE.NS at 7427.103515625
# Exit short position on JSWSTEEL.NS at 658.5031127929688
# Enter new short position on INFY.NS at 1577.90869140625
# Exit long position on BAJFINANCE.NS at 7335.54052734375
# Enter new long position on SHREECEM.NS at 30312.3203125
# Exit short position on INFY.NS at 1586.2957763671875
# Enter new short position on M&M.NS at 728.5076293945312
# Exit long position on SHREECEM.NS at 29749.53515625
# Enter new long position on KOTAKBANK.NS at 1996.4119873046875
# Exit short position on M&M.NS at 710.7027587890625
# Enter new short position on ADANIENT.NS at 1438.8172607421875
# Exit short position on ADANIENT.NS at 1528.4534912109375
# Enter new short position on TATASTEEL.NS at 53.61048889160156
# Exit long position on KOTAKBANK.NS at 2000.4517822265625
# Enter new long position on NTPC.NS at 126.48749542236328
# Exit short position on TATASTEEL.NS at 55.87432098388672
# Enter new short position on APOLLOHOSP.NS at 4502.16552734375
# Exit long position on NTPC.NS at 127.33458709716797
# Enter new long position on TATAMOTORS.NS at 374.175537109375
# Exit short position on APOLLOHOSP.NS at 4284.54345703125
# Enter new short position on SHREECEM.NS at 27629.201171875
# Exit short position on SHREECEM.NS at 27413.505859375
# Enter new short position on APOLLOHOSP.NS at 3987.58251953125
# Exit short position on APOLLOHOSP.NS at 4121.80908203125
# Enter new short position on BRITANNIA.NS at 3464.220703125
# Exit short position on BRITANNIA.NS at 3523.1337890625
# Enter new short position on TCS.NS at 3336.55908203125
# Exit short position on TCS.NS at 3278.164794921875
# Enter new short position on EICHERMOT.NS at 2456.16552734375
# Exit long position on TATAMOTORS.NS at 482.70135498046875
# Enter new long position on ICICIBANK.NS at 779.3721923828125
# Exit long position on ICICIBANK.NS at 758.2374267578125
# Enter new long position on ULTRACEMCO.NS at 7754.18359375
# Exit short position on EICHERMOT.NS at 2586.481201171875
# Enter new short position on JSWSTEEL.NS at 651.9856567382812
# Exit short position on JSWSTEEL.NS at 657.35302734375
# Enter new short position on INDUSINDBK.NS at 1029.8099365234375
# Exit long position on ULTRACEMCO.NS at 7755.75830078125
# Enter new long position on APOLLOHOSP.NS at 5045.20703125
# Exit short position on INDUSINDBK.NS at 906.0755615234375
# Enter new short position on SHREECEM.NS at 25786.57421875
# Exit long position on APOLLOHOSP.NS at 5246.10107421875
# Enter new long position on POWERGRID.NS at 128.1844940185547
# Exit long position on POWERGRID.NS at 129.96133422851562
# Enter new long position on TCS.NS at 3474.80810546875
# Exit short position on SHREECEM.NS at 25846.712890625
# Enter new short position on HEROMOTOCO.NS at 2265.13134765625
# Exit short position on HEROMOTOCO.NS at 2269.08740234375
# Enter new short position on KOTAKBANK.NS at 1868.3851318359375
# Exit long position on TCS.NS at 3420.62939453125
# Enter new long position on AXISBANK.NS at 709.4090576171875
# Exit long position on AXISBANK.NS at 685.9114379882812
# Enter new long position on INFY.NS at 1711.8546142578125
# Exit short position on KOTAKBANK.NS at 1770.432373046875
# Enter new short position on INDUSINDBK.NS at 827.4677734375
# Final Portfolio Value: ₹1732934.03
# Final Long Position: INFY.NS at 1711.8546142578125, Final Short Position: INDUSINDBK.NS at 827.4677734375
